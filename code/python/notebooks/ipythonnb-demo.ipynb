# %% [markdown]
# ## My first test on IPython notebook
#
# ### Plotting?

# %%
import numpy as np
import scipy
# %matplotlib inline
import matplotlib.pyplot as plt

# %% [markdown]
# Simply plot the sine function.

# %%
x = np.arange(0,10,0.1)
plt.plot(x,np.sin(x))
plt.show()
